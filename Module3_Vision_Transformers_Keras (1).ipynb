# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
cnn_model = load_model('best_model.keras')   # or .h5 depending on your file
cnn_model.summary()
feature_layer_name = cnn_model.layers[-2].name
print("Feature extraction layer:", feature_layer_name)
hybrid_model = build_cnn_vit_hybrid(
    cnn_model=cnn_model,
    feature_layer_name=feature_layer_name,
    num_classes=2
)
hybrid_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

hybrid_model.summary()
training_config = {
    "epochs": 5,
    "batch_size": 8,
    "optimizer": "Adam",
    "learning_rate": 1e-4,
    "loss": "categorical_crossentropy"
}

print("Training configuration:", training_config)
